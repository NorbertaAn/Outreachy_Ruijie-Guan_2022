# %%
import geopandas as gpd

# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 显示数据类型和前100行数据
print(type(china_gez_al2))
display(china_gez_al2.head(100))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#    country ISO3166_2   name                      gez_name  gez_code  \
# 0      CHN            China      Boreal coniferous forest        41
# 1      CHN            China        Boreal mountain system        43
# 2      CHN            China      Subtropical humid forest        21
# 3      CHN            China   Subtropical mountain system        25
# 4      CHN            China  Temperate continental forest        32
# 5      CHN            China              Temperate desert        34
# 6      CHN            China     Temperate mountain system        35
# 7      CHN            China              Temperate steppe        33
# 8      CHN            China         Tropical moist forest        12
# 9      CHN            China      Tropical mountain system        16
# 10     CHN            China           Tropical rainforest        11
#
#    gez_abbrev  adminlevel                                           geometry
# 0          Ba           2  MULTIPOLYGON (((130.74677 48.18124, 130.75225 ...
# 1          BM           2  POLYGON ((120.35734 52.61699, 120.35997 52.620...
# 2         SCf           2  MULTIPOLYGON (((110.55469 20.88397, 110.55427 ...
# 3          SM           2  MULTIPOLYGON (((105.88057 22.92104, 105.87537 ...
# 4        TeDc           2  MULTIPOLYGON (((119.64767 34.52533, 119.64770 ...
# 5       TeBWk           2  MULTIPOLYGON (((81.05737 44.10284, 81.03867 44...
# 6         TeM           2  MULTIPOLYGON (((119.91135 39.99713, 119.91098 ...
# 7       TeBSk           2  MULTIPOLYGON (((123.90427 49.42474, 123.58287 ...
# 8        TAwa           2  MULTIPOLYGON (((111.20874 15.78631, 111.20804 ...
# 9          TM           2  MULTIPOLYGON (((98.71257 25.90364, 98.70867 25...
# 10        TAr           2  MULTIPOLYGON (((107.57082 21.61434, 107.56717 ...

# %%
import geopandas as gpd
def column_std(df):
    """
    Standardizes column names by converting them to lowercase.
    """
    return df.rename(columns=lambda x: x.lower(), inplace=True)


# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 标准化列名
china_gez_al2.columns = column_std(china_gez_al2)

# 裁剪数据集以保留有关中国的数据
# 请注意，根据您的数据结构，可能需要调整下面的裁剪过程
china_data = clip_df(china_gez_al2, china_boundary)
china_data = china_data[['name', 'geometry']]

# 显示中国的生态地带数据
print("中国具有以下生态地带数据：")
print(china_data['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      13 china_gez_al2 = gpd.read_file(file_path_china_al2)
#      15 # 标准化列名
# ---> 16 china_gez_al2.columns = column_std(china_gez_al2)
#      18 # 裁剪数据集以保留有关中国的数据
#      19 # 请注意，根据您的数据结构，可能需要调整下面的裁剪过程
#      20 china_data = clip_df(china_gez_al2, china_boundary)
#
# File d:\ProgramData\anaconda3\lib\site-packages\geopandas\geodataframe.py:206, in GeoDataFrame.__setattr__(self, attr, val)
#     204     object.__setattr__(self, attr, val)
#     205 else:
# --> 206     super().__setattr__(attr, val)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:822, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
# --> 822     labels = ensure_index(labels)
#     823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7333, in ensure_index(index_like, copy)
#    7331         return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7332 else:
# -> 7333     return Index._with_infer(index_like, copy=copy)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:716, in Index._with_infer(cls, *args, **kwargs)
#     714 with warnings.catch_warnings():
#     715     warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 716     result = cls(*args, **kwargs)
#     718 if result.dtype == _dtype_obj and not result._is_multi:
#     719     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     720     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     721     # "ndarray[Any, Any]"
#     722     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:545, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     542     return klass._simple_new(arr, name)
#     544 elif is_scalar(data):
# --> 545     raise cls._scalar_data_error(data)
#     546 elif hasattr(data, "__array__"):
#     547     return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, None was passed

# %%
import geopandas as gpd

# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 标准化列名
column_std(china_gez_al2)

# 显示中国的生态地带数据
print("中国具有以下生态地带数据：")
print(china_gez_al2['name'])
# Out:
# 中国具有以下生态地带数据：
# 0     China
# 1     China
# 2     China
# 3     China
# 4     China
# 5     China
# 6     China
# 7     China
# 8     China
# 9     China
# 10    China
# Name: name, dtype: object

# %%
import json

# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 读取 JSON 文件
with open(file_path_china_al2, 'r') as json_file:
    data = json.load(json_file)

# 提取行名和列名
rows = data.get("features", [])
columns = list(rows[0]["properties"].keys()) if rows else []

# 打印行名和列名
print("行名：")
for row in rows:
    print(row["type"])

print("列名：")
print(columns)
# Out:
# 行名：
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# Feature
# 列名：
# ['country', 'ISO3166_2', 'name', 'gez_name', 'gez_code', 'gez_abbrev', 'adminlevel']

# %%
# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 标准化列名
china_gez_al2.columns = column_std(china_gez_al2)

# 提取行名和列名
rows = china_gez_al2.get("name", [])
columns = china_gez_al2.columns.tolist()

# 显示中国生态地带数据的行名和列名
print("行名：")
for row in rows:
    print(row)

print("列名：")
for column in columns:
    print(column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 china_gez_al2 = gpd.read_file(file_path_china_al2)
#       7 # 标准化列名
# ----> 8 china_gez_al2.columns = column_std(china_gez_al2)
#      10 # 提取行名和列名
#      11 rows = china_gez_al2.get("name", [])
#
# File d:\ProgramData\anaconda3\lib\site-packages\geopandas\geodataframe.py:206, in GeoDataFrame.__setattr__(self, attr, val)
#     204     object.__setattr__(self, attr, val)
#     205 else:
# --> 206     super().__setattr__(attr, val)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:822, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
# --> 822     labels = ensure_index(labels)
#     823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7333, in ensure_index(index_like, copy)
#    7331         return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7332 else:
# -> 7333     return Index._with_infer(index_like, copy=copy)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:716, in Index._with_infer(cls, *args, **kwargs)
#     714 with warnings.catch_warnings():
#     715     warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 716     result = cls(*args, **kwargs)
#     718 if result.dtype == _dtype_obj and not result._is_multi:
#     719     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     720     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     721     # "ndarray[Any, Any]"
#     722     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:545, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     542     return klass._simple_new(arr, name)
#     544 elif is_scalar(data):
# --> 545     raise cls._scalar_data_error(data)
#     546 elif hasattr(data, "__array__"):
#     547     return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, None was passed

# %%
# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 显示数据的前几行
display(china_gez_al2.head(5))
# Out:
#   country ISO3166_2   name                      gez_name  gez_code gez_abbrev  \
# 0     CHN            China      Boreal coniferous forest        41         Ba
# 1     CHN            China        Boreal mountain system        43         BM
# 2     CHN            China      Subtropical humid forest        21        SCf
# 3     CHN            China   Subtropical mountain system        25         SM
# 4     CHN            China  Temperate continental forest        32       TeDc
#
#    adminlevel                                           geometry
# 0           2  MULTIPOLYGON (((130.74677 48.18124, 130.75225 ...
# 1           2  POLYGON ((120.35734 52.61699, 120.35997 52.620...
# 2           2  MULTIPOLYGON (((110.55469 20.88397, 110.55427 ...
# 3           2  MULTIPOLYGON (((105.88057 22.92104, 105.87537 ...
# 4           2  MULTIPOLYGON (((119.64767 34.52533, 119.64770 ...

# %%
# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 显示数据的前几行
display(china_gez_al2.head(5))

# 获取行名
rows = china_gez_al2.get("name", [])
print("中国具有以下生态地带数据：")
for row in rows:
    print(row)

# 获取列名
columns = china_gez_al2.columns.tolist()
print("列名：")
for column in columns:
    print(column)
# Out:
#   country ISO3166_2   name                      gez_name  gez_code gez_abbrev  \
# 0     CHN            China      Boreal coniferous forest        41         Ba
# 1     CHN            China        Boreal mountain system        43         BM
# 2     CHN            China      Subtropical humid forest        21        SCf
# 3     CHN            China   Subtropical mountain system        25         SM
# 4     CHN            China  Temperate continental forest        32       TeDc
#
#    adminlevel                                           geometry
# 0           2  MULTIPOLYGON (((130.74677 48.18124, 130.75225 ...
# 1           2  POLYGON ((120.35734 52.61699, 120.35997 52.620...
# 2           2  MULTIPOLYGON (((110.55469 20.88397, 110.55427 ...
# 3           2  MULTIPOLYGON (((105.88057 22.92104, 105.87537 ...
# 4           2  MULTIPOLYGON (((119.64767 34.52533, 119.64770 ...
# 中国具有以下生态地带数据：
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# 列名：
# country
# ISO3166_2
# name
# gez_name
# gez_code
# gez_abbrev
# adminlevel
# geometry

# %%
# 文件路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 获取行名
rows = china_gez_al2['name'].unique()
print("中国具有以下生态地带数据：")
for row in rows:
    print(row)

# 获取列名
columns = china_gez_al2.columns.tolist()
print("列名：")
for column in columns:
    print(column)
# Out:
# 中国具有以下生态地带数据：
# China
# 列名：
# country
# ISO3166_2
# name
# gez_name
# gez_code
# gez_abbrev
# adminlevel
# geometry

# %%
# 文件路径和文件名
file_path_china_bio_hotspot = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 使用 geopandas 的 read_file 函数加载数据
china_bio_hotspot_df = gpd.read_file(file_path_china_bio_hotspot)

# 输出 GeoDataFrame 的前几行
print(china_bio_hotspot_df.head())

# 获取列名
columns = china_bio_hotspot_df.columns.tolist()
print("列名：")
for column in columns:
    print(column)
# Out:
#   country ISO3166_2   name                      gez_name  gez_code gez_abbrev  \
# 0     CHN            China      Boreal coniferous forest        41         Ba
# 1     CHN            China        Boreal mountain system        43         BM
# 2     CHN            China      Subtropical humid forest        21        SCf
# 3     CHN            China   Subtropical mountain system        25         SM
# 4     CHN            China  Temperate continental forest        32       TeDc
#
#    adminlevel                                           geometry
# 0           2  MULTIPOLYGON (((130.74677 48.18124, 130.75225 ...
# 1           2  POLYGON ((120.35734 52.61699, 120.35997 52.620...
# 2           2  MULTIPOLYGON (((110.55469 20.88397, 110.55427 ...
# 3           2  MULTIPOLYGON (((105.88057 22.92104, 105.87537 ...
# 4           2  MULTIPOLYGON (((119.64767 34.52533, 119.64770 ...
# 列名：
# country
# ISO3166_2
# name
# gez_name
# gez_code
# gez_abbrev
# adminlevel
# geometry

# %%
# 可视化数据
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 15))
ax1.set_title('BIODIVERSITY HOTSPOTS IN CHINA')
ax2.set_title('BIODIVERSITY HOTSPOTS IN LIAONING')

# 替换下面的变量名为您的数据
plot_boundary(china_boundary, ax1)
plot_feature(china_bio_hotspot_df, ax1, "name")
plot_feature(liaoning_bio_hotspot_df, ax2, "name")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 可视化数据
# ----> 2 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 15))
#       3 ax1.set_title('BIODIVERSITY HOTSPOTS IN CHINA')
#       4 ax2.set_title('BIODIVERSITY HOTSPOTS IN LIAONING')
#
# NameError: name 'plt' is not defined

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 中国的数据路径和文件名
file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111823Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'

# 导入中国的数据
china_gez_al2 = gpd.read_file(file_path_china_al2)

# 标准化列名
china_gez_al2.columns = map(str.lower, china_gez_al2.columns)

# 可视化数据
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_title('Ecological Zones in China')
china_gez_al2.plot(column='name', legend=True, cmap='tab20', ax=ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:\Users\BOSS Guan\Desktop\Outreachy\moja\Bioclimatic&EcologicalZones-20231018T111823Z-002\Bioclimatic_EcologicalZones\Global_Ecological_Zone_GEZ\byCountry\CHN_AL2_China_GEZ.json: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[13], line 8
#       5 file_path_china_al2 = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111823Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byCountry\\CHN_AL2_China_GEZ.json'
#       7 # 导入中国的数据
# ----> 8 china_gez_al2 = gpd.read_file(file_path_china_al2)
#      10 # 标准化列名
#      11 china_gez_al2.columns = map(str.lower, china_gez_al2.columns)
#
# File d:\ProgramData\anaconda3\lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
#     298         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     299     )
#     301 else:
#     302     raise ValueError(f"unknown engine '{engine}'")
#
# File d:\ProgramData\anaconda3\lib\site-packages\geopandas\io\file.py:338, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     335     reader = fiona.open
#     337 with fiona_env():
# --> 338     with reader(path_or_bytes, **kwargs) as features:
#     339         crs = features.crs_wkt
#     340         # attempt to get EPSG code
#
# File d:\ProgramData\anaconda3\lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File d:\ProgramData\anaconda3\lib\site-packages\fiona\__init__.py:305, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     302     path = parse_path(fp)
#     304 if mode in ("a", "r"):
# --> 305     colxn = Collection(
#     306         path,
#     307         mode,
#     308         driver=driver,
#     309         encoding=encoding,
#     310         layer=layer,
#     311         enabled_drivers=enabled_drivers,
#     312         allow_unsupported_drivers=allow_unsupported_drivers,
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
#     316     colxn = Collection(
#     317         path,
#     318         mode,
#    (...)
#     327         **kwargs
#     328     )
#
# File d:\ProgramData\anaconda3\lib\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: C:\Users\BOSS Guan\Desktop\Outreachy\moja\Bioclimatic&EcologicalZones-20231018T111823Z-002\Bioclimatic_EcologicalZones\Global_Ecological_Zone_GEZ\byCountry\CHN_AL2_China_GEZ.json: No such file or directory

# %%
# !pip install geopandas matplotlib
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError(0, 'Error'))': /simple/geopandas/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError(0, 'Error'))': /simple/geopandas/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError(0, 'Error'))': /simple/geopandas/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError(0, 'Error'))': /simple/geopandas/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError(0, 'Error'))': /simple/geopandas/
# ERROR: Could not find a version that satisfies the requirement geopandas (from versions: none)
# ERROR: No matching distribution found for geopandas
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install geopandas matplotlib

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 定义中国行政边界的文件路径
china_boundary_file = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Administrative-20231019T110829Z-002\\Administrative\\Boundaries\\CHN_AL2_China.json'

# 定义辽宁省生态地带数据文件路径
liaoning_gez_file = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Bioclimatic&EcologicalZones-20231018T111649Z-002\\Bioclimatic_EcologicalZones\\Global_Ecological_Zone_GEZ\\byStateGEZ\\CHN\\CHN_AL4_Liaoning_GEZ.json'

# 读取中国行政边界数据
china_boundary = gpd.read_file(china_boundary_file)

# 读取辽宁省生态地带数据
liaoning_gez = gpd.read_file(liaoning_gez_file)

# 可视化中国的行政边界
china_boundary.plot()
plt.title('Administrative Boundary of China')
plt.show()

# 可视化辽宁省的生态地带数据
liaoning_gez.plot()
plt.title('Ecological Zones in Liaoning Province')
plt.show()
