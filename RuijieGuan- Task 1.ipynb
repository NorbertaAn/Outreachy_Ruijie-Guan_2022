# %%
#Hello, everyone, I'm going to work now. 1. Now I have a problem:I need to look at the specific data set, find the exact column name containing land area information, and replace it with the code for statistical analysis.  I don't know how or where to get the exact column name.##
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the Data
# Specify the full path to your data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)

# 2. View Data Column Names
# View the first few rows of the data
print(data.head())

# Get column names
column_names = data.columns
print("Column Names:", column_names)

# 3. Data Visualization
# Plot a map of China
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. Statistical Analysis
# Calculate the average and maximum area
# Replace 'your_area_column' with the actual column name that contains land area information.
average_area = data['your_area_column'].mean()
max_area = data['your_area_column'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load Data
# Specify the full path to the data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)

# 2. Data Exploration
# View the first few rows of data
print(data.head())

# View data types and column names
print(data.dtypes)
print(data.columns)

# 3. Data Visualization
# Plot a map of China
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. Statistical Analysis
# Calculate the average and maximum area
average_area = data['area'].mean()
max_area = data['area'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# country         object
# ISO3166_2       object
# name            object
# SNAME           object
# mg_code          int64
# IPCC            object
# adminlevel       int64
# geometry      geometry
# dtype: object
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load Data
# Specify the full path to the data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)# 2. 数据探索
# 查看前几行数据
print(data.head())

# 查看数据列名
print(data.columns)

# 假设您发现列名为 'land_area' 包含了土地面积信息
# 3. 数据可视化
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. 统计分析
# 计算面积的平均值和最大值
average_area = data['land_area'].mean()
max_area = data['land_area'].max()
print(f'Average Land Area: {average_area}')
print(f'Max Land Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. 加载数据
# 指定数据文件的完整路径
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 加载数据
data = gpd.read_file(file_path)

# 2. 查看数据列名
# 查看前几行数据
print(data.head())

# 查看数据列名
print(data.columns)

# 3. 数据可视化
# 绘制中国地图
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. 统计分析
# 根据实际数据列名计算平均值和最大值
# 例如，如果列名是 'land_area'，则用 'land_area' 替换 'your_column_name'。
average_area = data['your_column_name'].mean()
max_area = data['your_column_name'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')

# 5. 地理空间分析
# 如果数据包含地理坐标信息，您可以进行地理空间分析，例如计算距离

# 6. 数据解释和见解
# 在Jupyter Notebook中添加解释和见解

# 7. 创建Jupyter Notebook并记录
# 打开Jupyter Notebook，创建一个新的Notebook，将上述代码粘贴到Notebook中，然后记录您的分析结果。

# 8. 提交和拉取请求
# 使用Git将Notebook和相关文件提交到您的GitHub仓库，然后创建一个拉取请求。

# 9. 分享链接
# 分享拉取请求的链接到Moja Global Slack社区的 #outreachy 频道中。
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
import geopandas as gpd

# 指定数据文件的完整路径
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 加载 JSON 文件
data = gpd.read_file(file_path)

# 查看数据前几行
print(data.head())

# 获取列名
column_names = data.columns
print("Column Names:", column_names)
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')

# %%
import geopandas as gpd

# 指定数据文件的完整路径
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 加载 JSON 文件
data = gpd.read_file(file_path)

# 查看数据前几行
print(data.head())

# 获取列名
column_names = data.columns
print("Column Names:", column_names)      import matplotlib.pyplot as plt

# 绘制地图
data.plot()
plt.title('China Land Sector Map')
plt.show()
# Out:
#   Cell In[9], line 14
#     print("Column Names:", column_names)      import matplotlib.pyplot as plt
#                                               ^
# SyntaxError: invalid syntax

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. 加载数据
# 指定数据文件的完整路径
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 加载数据
data = gpd.read_file(file_path)

# 2. 查看数据列名
# 查看前几行数据
print(data.head())

# 获取列名
column_names = data.columns
print("Column Names:", column_names)

# 3. 数据可视化
# 绘制中国地图
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. 统计分析
# 根据实际数据列名计算平均值和最大值
# 例如，如果列名是 'land_area'，则用 'land_area' 替换 'your_area_column'。
average_area = data['your_area_column'].mean()
max_area = data['your_area_column'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
print(data.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(data.columns)
#
# NameError: name 'data' is not defined

# %%
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'
data = gpd.read_file(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'
# ----> 2 data = gpd.read_file(file_path)
#
# NameError: name 'gpd' is not defined

# %%
import json

# 指定 JSON 文件的路径
json_file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 读取 JSON 文件
with open(json_file_path, 'r') as file:
    data = json.load(file)

# 显示前几行数据
for i, record in enumerate(data):
    if i < 5:  # 只显示前 5 行数据
        print(record)
# Out:
# type
# name
# features

# %%
import json

# 指定 JSON 文件的路径
json_file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# 读取 JSON 文件
with open(json_file_path, 'r') as file:
    data = json.load(file)

# 访问 "features" 列
features = data["features"]

# 显示前几行数据以查看列名
for feature in features:
    properties = feature["properties"]
    # 假设土地面积信息列名为 "land_area"，你需要找到正确的列名并替换下面的 "your_area_column"
    if "land_area" in properties:
        print("Land Area:", properties["land_area"])
        break

# %%
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# 1. Load the Data
# Specify the full path to your data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)

# 2. View Data Column Names
# View the first few rows of the data
print(data.head())

# Get column names
column_names = data.columns
print("Column Names:", column_names)

# 3. Data Visualization
# Plot a map of China
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. Statistical Analysis
# Calculate the average and maximum area
# Replace 'your_area_column' with the actual column name that contains land area information.
average_area = data['your_area_column'].mean()
max_area = data['your_area_column'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the Data
# Specify the full path to your data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)

# 2. View Data Column Names
# View the first few rows of the data
print(data.head())

# Get column names
column_names = data.columns
print("Column Names:", column_names)

# 3. Data Visualization
# Plot a map of China
data.plot()
plt.title('China Land Sector Map')
plt.show()

# 4. Statistical Analysis
# Calculate the average and maximum area
# Replace 'your_area_column' with the actual column name that contains land area information.
average_area = data['your_area_column'].mean()
max_area = data['your_area_column'].max()
print(f'Average Area: {average_area}')
print(f'Max Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %%
# Calculate land area from the 'geometry' column
data['land_area'] = data['geometry'].area

# Now you can perform statistical analysis on the 'land_area' column
average_area = data['land_area'].mean()
max_area = data['land_area'].max()
print(f'Average Land Area: {average_area}')
print(f'Max Land Area: {max_area}')
# Out:
# Average Land Area: 8.403459061147439
# Max Land Area: 75.30440230984594
# C:\Users\BOSS Guan\AppData\Local\Temp\ipykernel_15240\3374148933.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['land_area'] = data['geometry'].area

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the Data
# Specify the full path to your data file
file_path = 'C:\\Users\\BOSS Guan\\Desktop\\Outreachy\\moja\\Soil-20231018T111823Z-002\\Soil\\World Soil Resources\\byStateWSR\\CHN\\CHN_ALL_states_WSR.json'

# Load the data
data = gpd.read_file(file_path)

# 2. View Data Column Names
# View the first few rows of the data
print(data.head())

# Get column names
column_names = data.columns
print("Column Names:", column_names)

# 3. Data Visualization
# Plot a map of China
data.plot()
plt.title('China Land Sector Map')
plt.show()

# Calculate land area from the 'geometry' column
data['land_area'] = data['geometry'].area

# 4. Statistical Analysis
# Perform statistical analysis on the 'land_area' column
average_area = data['land_area'].mean()
max_area = data['land_area'].max()
print(f'Average Land Area: {average_area}')
print(f'Max Land Area: {max_area}')
# Out:
#   country ISO3166_2     name SNAME  mg_code       IPCC  adminlevel  \
# 0     CHN     CN-AH    Anhui    AC       23    Acrisol           4
# 1     CHN     CN-AH    Anhui    AT       13  Anthrosol           4
# 2     CHN     CN-AH    Anhui    FL       20   Fluvisol           4
# 3     CHN     CN-AH    Anhui    LV       12    Luvisol           4
# 4     CHN     CN-BJ  Beijing    LP       18   Leptosol           4
#
#                                             geometry
# 0  POLYGON ((119.24516 30.56674, 119.17275 30.601...
# 1  MULTIPOLYGON (((118.81232 32.58298, 118.81235 ...
# 2  MULTIPOLYGON (((118.95785 32.94872, 118.95780 ...
# 3  POLYGON ((117.36638 32.00399, 117.42886 32.021...
# 4  POLYGON ((117.38328 40.22661, 117.38086 40.225...
# Column Names: Index(['country', 'ISO3166_2', 'name', 'SNAME', 'mg_code', 'IPCC',
#        'adminlevel', 'geometry'],
#       dtype='object')
# Average Land Area: 8.403459061147439
# Max Land Area: 75.30440230984594
# ...
